# %%
import pandas as pd
import torch
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import r2_score, mean_squared_error

# %%
# Load direct from split folder
train_df = pd.read_csv('../data/split/train/train.csv')
test_df  = pd.read_csv('../data/split/test/test.csv')

#drop address
train_df = train_df.drop(columns=['address'])
test_df = test_df.drop(columns=['address'])

# %%
# Encode & features
for df in [train_df, test_df]:
    df["region_encode"] = LabelEncoder().fit_transform(df["region"])
    df["location_value"] = df.groupby("region")["price"].transform("mean")
    df["area_location"] = df["area"] * df["location_value"]

features = ["area", "bedrooms", "bathrooms", "area_location", "region_encode"]

# %%
# X, y
X_train = train_df[features].values
y_train = train_df["price"]

X_test = test_df[features].values
y_test = test_df["price"]

# Không dùng scaler; dùng giá trị gốc
a = 1  # no-op to keep cell structure consistent

# %%
# Convert to tensor
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)

X_test  = torch.tensor(X_test, dtype=torch.float32)
y_test  = torch.tensor(y_test, dtype=torch.float32)

# %%
# Model
model = torch.nn.Linear(X_train.shape[1], 1)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_fn = torch.nn.MSELoss()

# %%
# Train
for _ in range(2000):
    optimizer.zero_grad()
    pred = model(X_train)
    loss = loss_fn(pred, y_train)
    loss.backward()
    optimizer.step()
# Out:
# d:\HCMUS\HK8\ML Introduction\lab\lab1\INTROML\.venv\Lib\site-packages\torch\nn\modules\loss.py:634: UserWarning: Using a target size (torch.Size([1600])) that is different to the input size (torch.Size([1600, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
# Print weights and bias
print("\n=== MODEL PARAMETERS ===")
print("Weights:", model.weight.detach().numpy())
print("Bias:", model.bias.detach().numpy())

# Evaluate
y_pred = model(X_test).detach().numpy()
print("\n=== EVALUATION ===")
print("R²:", r2_score(y_test, y_pred))
print("RMSE:", (mean_squared_error(y_test, y_pred)) ** 0.5)
# Out:
# === MODEL PARAMETERS ===
# Weights: [[-7.6615258e-08  1.0762152e-07 -1.0840742e-07  7.8788823e-08
#   -2.0817278e-07]]
# Bias: [8.375918]
#
# === EVALUATION ===
# R²: -0.0029233694076538086
# RMSE: 11.444142564991559
